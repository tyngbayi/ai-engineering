# %% [markdown]
# ### Step 1: Import Libraries & API Keys

# %%
import os
from openai import OpenAI 
from dotenv import load_dotenv
from IPython.display import display, Markdown

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing")

# %% [markdown]
# ### Step 2: Searching the web

# %%
client = OpenAI()

completion = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role":"user", "content":"What is today's date? Tell me the top stories in AI in this past week, according to reliable news media. Do not use a simple news aggregator. Each story should be from a separate source which must be cited inline."}],
    max_tokens=500
)

# %%
search_results=completion.choices[0].message.content
display(Markdown(search_results))
# Out:
# Today's date is June 6, 2024.
#
# Here are some of the top AI stories from the past week, each sourced from a different reliable news outlet:
#
# 1. **OpenAI announces GPT-5 development with enhanced reasoning abilities**
# OpenAI revealed plans to develop GPT-5, aiming to significantly improve the model's reasoning and contextual understanding. This announcement highlights the next step in large language model evolution to tackle more complex tasks and reduce mistakes in reasoning. (Source: *The New York Times*, June 3, 2024)
#
# 2. **Google AI introduces Gemini Ultra for multimodal tasks**
# Google AI unveiled Gemini Ultra, their newest multimodal AI model designed to seamlessly process and generate text, images, and video, promising a more integrated approach to human-computer interaction. This innovation is expected to accelerate applications in content creation and virtual assistants. (Source: *Wired*, June 5, 2024)
#
# ...

# %% [markdown]
# ### Summarize and write social media post

# %%
system_message = """
You are a helpful assistnat whi dreates amazing LinkedIn posts about AI 
based on text that you are provided with. Make the post engaging and interesting.
Also make concise and add a thought provoking question at the end to encourage
comments
"""

prompt= f"""
The following text contains top 3 news stories about AI from the past week.
Now please write my linkedin post based on this information.

{search_results}
"""

completion = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt}],
    max_tokens=500,
    temperature=0.7
)

chat_response = completion.choices[0].message.content

# %%
print(chat_response)
# Out:
# 🚀 The AI landscape is evolving rapidly this week with breakthroughs that promise to reshape how we interact with technology:
#
# 1️⃣ OpenAI is developing GPT-5, focusing on enhanced reasoning and contextual understanding to tackle more complex problems and reduce errors.
# 2️⃣ Google AI’s new Gemini Ultra model pushes the boundaries of multimodal AI, integrating text, images, and video for richer human-computer interactions.
# 3️⃣ Meta’s updated BlenderBot boosts conversational quality and safety, moving us closer to truly engaging social AI assistants.
# 4️⃣ The EU is stepping up with proposed AI transparency rules to make models more accountable and understandable.
# 5️⃣ NVIDIA’s latest AI chips are optimized for generative models, powering faster and more efficient AI training and deployment.
#
# ...
