# %% [markdown]
# ### Step 1 Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])
    
client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role":"system", "content":"You are a helpful assistant."},
              {"role":"user", "content":"Next week I am travelling to Spain."}]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# That sounds exciting! Do you need any tips or information for your trip to Spain? For example, recommendations on places to visit, local customs, language phrases, or travel advice?

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role":"system", "content":"You are a helpful assistant."},
              {"role":"user", "content":"Where am I travelling next week?"}]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# I’m not sure where you are traveling next week. Could you please provide more details?

# %% [markdown]
# ### In theory... (doing it manually for illustration)

# %%
messages = [{"role":"system", "content":"You are a helpful assistant."},
            {"role":"user", "content":"Next week I am travelling to Spain."},
            {"role":"assistant", "content":"That sounds exciting! Do you need any tips or information for your trip to Spain? For example, recommendations on places to visit, local customs, language tips, or travel advice?"},
            {"role":"user", "content":"Where am I travelling next week?"}]

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# You are travelling to Spain next week.

# %% [markdown]
# ### Now: no manually

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role":"assistant", "content":reply})

#display(Markdown(reply))

from pprint import pprint
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week I am travelling to Spain.', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information for '
#              'your trip to Spain? For example, recommendations on places to '
#              'visit, local customs, language tips, or travel advice?',
#   'role': 'assistant'},
#  {'content': 'Where am I travelling next week?', 'role': 'user'},
#  {'content': 'You are travelling to Spain next week.', 'role': 'assistant'}]

# %%
messages.append({"role":"user", "content":"What is the capital?"})

# %%
messages
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant.'},
#  {'role': 'user', 'content': 'Next week I am travelling to Spain.'},
#  {'role': 'assistant',
#   'content': 'That sounds exciting! Do you need any tips or information for your trip to Spain? For example, recommendations on places to visit, local customs, language tips, or travel advice?'},
#  {'role': 'user', 'content': 'Where am I travelling next week?'},
#  {'role': 'assistant', 'content': 'You are travelling to Spain next week.'},
#  {'role': 'user', 'content': 'What is the capital?'}]

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role":"assistant", "content":reply})

pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': 'Next week I am travelling to Spain.', 'role': 'user'},
#  {'content': 'That sounds exciting! Do you need any tips or information for '
#              'your trip to Spain? For example, recommendations on places to '
#              'visit, local customs, language tips, or travel advice?',
#   'role': 'assistant'},
#  {'content': 'Where am I travelling next week?', 'role': 'user'},
#  {'content': 'You are travelling to Spain next week.', 'role': 'assistant'},
#  {'content': 'What is the capital?', 'role': 'user'},
#  {'content': 'The capital of Spain is Madrid.', 'role': 'assistant'}]
