# %% [markdown]
# ### Step 1 Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role":"user", "content":"what is an okapi"}]
)

answer = response.choices[0].message.content

print(answer)
# Out:
# An **okapi** is a unique and rare mammal native to the dense rainforests of the Democratic Republic of Congo in Central Africa. Despite its zebra-like stripes on its legs, the okapi is actually more closely related to the giraffe. It has a body shape somewhat similar to a horse or deer, with a long neck (though shorter than a giraffe's), large ears, and a velvety dark brown coat contrasted with white horizontal stripes on its legs and hindquarters, which help with camouflage in its forest environment.
#
# Here are some key facts about the okapi:
#
# - **Scientific name:** *Okapia johnstoni*
# - **Family:** Giraffidae (same family as giraffes)
# - **Diet:** Herbivorous; feeds on leaves, buds, grasses, ferns, and fruits.
# - **Behavior:** Generally solitary and elusive, making it difficult to observe in the wild.
# - **Conservation status:** Classified as Endangered due to habitat loss and hunting.
#
# The okapi was unknown to the Western world until the early 20th century and is sometimes called the "forest giraffe" because of its close relation to the giraffe.
